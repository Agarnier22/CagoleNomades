# %%
import pandas as pd
import numpy as np
import excel2json

# %%
excel2json.convert_from_file('../cagoleNomade/app/assets/json/produits.xlsx')
# Out:
# Excel xlsx file; not supported
# 'NoneType' object is not iterable

# %%
data=pd.read_json('../cagoleNomade/app/assets/json/produits.json')

# %%
data
# Out:
#                              Nom_article  Prix  \
# 0    Bob en Voile de Bateau 100% upcyclé    45
# 1          Bob Reversible 100% upcycling    39
# 2                              Bonnet CN    35
# 3                          Gymbag Nomade    25
# 4              Le Porte Gourde Bleu Ciel    39
# 5               Le Porte Gourde Bordeaux    39
# 6             Magali - Prot�ge Passeport    29
# 7              Manon - Prot�ge Passeport    29
# 8             Marius - Prot�ge Passeport    29
# 9        Robe Unisex (Version Coton Bio)    39
# 10  Sweatshirt Capuche Unisex - Bordeaux    65
# 11      Sweatshirt Capuche Unisex - Navy    65
# 12              Sweatshirt Unisex - Gris    58
# 13                       Tote Bag Pri�re    25
# 14              Trousse de Voyage Nomade    18
# 15    T-shirt Cagole Nomade x Lenysterie    39
# 16                Tshirt Unisex Massilia    39
#
#                                           Description  \
# ...
